# %%
# %pip install pyreadstat
# %restart_python
# Out:
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import pyreadstat
path = "/Volumes/data_engineering/bronze/brfss_2024_xpt_data/LLCP2024.XPT_"

# pyreadstat reads XPT metadata → numeric cols are float64, char cols stay object
df, meta = pyreadstat.read_xport(path, encoding="latin1")
print(df.shape, df.dtypes.value_counts().to_dict())

(spark.createDataFrame(df)
    .write.mode("overwrite")
    .option("overwriteSchema", "true")
    .saveAsTable("data_engineering.bronze.brfss_2024"))
# Out:
# (457670, 301) {dtype('float64'): 296, dtype('O'): 5}
